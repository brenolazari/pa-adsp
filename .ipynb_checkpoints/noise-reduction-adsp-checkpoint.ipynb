# %%
# EXEMPLO DE REMOCAO DE RUIDO COMECA AQUI

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16,12]
plt.rcParams.update({'font.size': 18})

# criar um sinal simples com duas frequencias
# aqui nos vamos substituir pelo nosso sinal de entrada teste, com o auxilio do audacity 
dt = 0.001
t = np.arange(0, 1, dt)
f = np.sin(2*np.pi*50*t) + np.sin(2*np.pi*120*t)
# lendo arquivo de audio
f_clean = f

# adiciona ruido
# aqui nos vamos substituir pelo nosso sinal de ruido, com o auxilio do audacity 
f = f + 2.5*np.random.randn(len(t))
#fs_rate2, signal2 = wavfile.read("FINAL.wav")

# plota os graficos so para visualizar
plt.plot(t, f, color='c', LineWidth=1.5, label='Noisy')
plt.plot(t, f_clean, color='k', LineWidth=2, label='Clean')
plt.xlim(t[0], t[-1])
plt.legend()

# %%
# VOU METER A PA
import IPython
import matplotlib.pyplot as plt
import scipy
from scipy.fftpack import fft
from scipy.io import wavfile # get the api

plt.rcParams['figure.figsize'] = [16,12]
plt.rcParams.update({'font.size': 18})

rate, data = wavfile.read('teste.wav') # load the data
fs2, noise = wavfile.read('traffic12.wav') # load the data

data = data
noisy = data + noise

fig, ax = plt.subplots(figsize=(20,4))
ax.plot(noisy)

IPython.display.Audio(data=noisy
, rate=rate)
# Out:
# C:\Users\Breno.Silva\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   # This is added back by InteractiveShellApp.init_path()
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def filter_signal(signal, threshold=1e8):
    fourier = rfft(signal)
    frequencies = rfftfreq(signal.size, d=20e-3/signal.size)
    fourier[frequencies > threshold] = 0
    return irfft(fourier)

N = data.shape[0] #[0]
print ("Complete Samplings N", N)

# quantos segundos eh o audio
type(N)
secs = N / float(rate)
print ("secs", secs)

# intervalo entre cada sample
Ts = 1.0/rate
print ("Timestep between samples Ts", Ts)

# pega numpy array
t = scipy.arange(0, secs, Ts) # time vector as scipy arange field / numpy.ndarray

noisy = data + 200.5*np.random.randn(len(t))

# #f = np.sin(2*np.pi*50*t) + np.sin(2*np.pi*120*t)
# f = data
# # # lendo arquivo de audio
# f_clean = f

# # noisy = f + noise
# # dt = 0.001
# # t = np.arange(0, 1, dt)
# # f = np.sin(2*np.pi*50*t) + np.sin(2*np.pi*120*t)
# # # lendo arquivo de audio
# # f_clean = f

# # # adiciona ruido
# # # aqui nos vamos substituir pelo nosso sinal de ruido, com o auxilio do audacity 
# #f = f + 2.5*np.random.randn(len(t))

# # computa a FFT
# n = len(t)
# # compute the fft
# fhat = np.fft.fft(noisy,n)
# # power sepectrum 
# PSD = fhat * np.conj(fhat) / n
# # create x-axis of frequencies
# freq = (1/(Ts*n)) * np.arange(n)
# # only plot the first half of
# L = np.arange(1, np.floor(n/2), dtype = 'int')
              
# # usa PSD (power spectre) 
# indices = PSD > 4 # acha todas as frequencias maior que esse threshold
# PSDclean = PSD * indices # zera as outras
# fhat = indices * fhat # zera os menores coeficientes de Fourier em Y
# ffilt = np.fft.ifft(fhat) # faz a FFT inversa para pegar o sinal filtrado

# # ::::::::::::::: PLOTS ::::::::::::::::::::::::::
# fig, axs = plt.subplots(3,1)

# plt.sca(axs[0])
# plt.plot(t, noisy, color='c', LineWidth=1.5, label='Noisy')
# plt.plot(t, data, color='k', LineWidth=2, label='Clean')
# plt.xlim(t[0], t[-1])
# plt.legend()

# # power spectrum density
# plt.sca(axs[1])
# plt.plot(t, ffilt, color='k', LineWidth=1.5, label='Filtered')
# plt.xlim(t[0], t[-1])
# plt.legend()

# plt.sca(axs[2])
# plt.plot(freq[L], PSD[L], color='c', LineWidth=2, label='Noisy')
# plt.plot(freq[L], PSDclean[L], color='k', LineWidth=1.5, label='Filtered')
# plt.xlim(freq[L[0]], 2000)
# plt.legend()

# plt.show()
# Out:
# Complete Samplings N 720000
# secs 15.0
# Timestep between samples Ts 2.0833333333333333e-05
# C:\Users\Breno.Silva\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: DeprecationWarning: scipy.arange is deprecated and will be removed in SciPy 2.0.0, use numpy.arange instead

# %%
IPython.display.Audio(data=noisy, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
